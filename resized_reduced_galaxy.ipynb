# %% [markdown]
# <a href="https://colab.research.google.com/github/ucbahallaou/w207_final_project/blob/main/resized_reduced_galaxy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-35d70985-2758-49bf-baf9-dd9e5c6ec22f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35d70985-2758-49bf-baf9-dd9e5c6ec22f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d robertmifsud/resized-reduced-gz2-images
# Out:
# ...
# 100% 1.80G/1.80G [00:19<00:00, 121MB/s]
# 100% 1.80G/1.80G [00:19<00:00, 98.6MB/s]

# %%
# !unzip resized-reduced-gz2-images.zip -d content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210471.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210481.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210519.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210581.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210593.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210610.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210619.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210638.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/210663.jpg
#   inflating: content/images_E_S_SB_69x69_a_03/images_E_S_SB_69x69_a_03_train/SB/21069.jpg
# ...

# %%
import pandas as pd
df = pd.read_csv('content/3class_map_a(p).csv')

# %%
df
# Out:
#         Unnamed: 0            dr7objid  asset_id gz2class  \
# 0                0  587732591714893851     58957     Sc+t
# 1                1  588009368545984617    193641     Sb+t
# 2                2  587732484359913515     55934       Ei
# 3                3  587741723357282317    158501     Sc+t
# 4                4  587738410866966577    110939       Er
# ...            ...                 ...       ...      ...
# 206163      206163  587741490371625059    262969       Ec
# 206164      206164  587731174917669027    275883    Ei(i)
# 206165      206165  587731512070177108    282536       Ei
# 206166      206166  587731513145688256    284172    Ei(i)
# 206167      206167  588015507679805636    288961       Ec
#
#         total_classifications  total_votes  agreement
# 0                          45          342   1.000000
# 1                          42          332   1.000000
# 2                          36          125   0.384527
# ...

# %%
df['total_classifications'].hist()
# Out:
# <Axes: >

# %%
df['total_votes'].hist()
# Out:
# <Axes: >
